# %% [markdown]
# # Demo:
# # Categorizing UFS Input Data Files by UFS Weather Model Application-to-Physics Suite  & Regression Tests
#
# ### __Introduction__
#
# There is a need for developers/users using the UFS Weather Model to be able to determine what data is required for a given UFS Weather Model Application-to-Physics Suite build as well as for a given unique UFS weather model application's regression test. Currently, a reference table does not exist for which will map the UFS Application-to-Physics Suite to their corresponding required list of data files nor a reference table for which will map the UFS weather model application's regression tests to their required list of data files.
# According to the current structure of the UFS weather model framework, the details are hidden within it's regression test framework scripts -- in which each unique regression test (listed within the regression test framework's **rt.conf** script) is represented by a unique "test" script (within ufs-weather-model repo's **/tests/tests**). Each unique "test" script will then call unique configuration files residing within the following ufs-weather-model repo's folders:
#
# - **/fv3_conf**
# - **/parm file**
#
# Note: Each unique regression test can only be applicable to a unique UFS Weather Model Application build.
#
# ### __Purpose__
#
# The purpose of the tool is to extract additional information regarding the input and baseline datasets residing within the RDHPCS relationship to the UFS Weather Model Application-to-Physics Suite & their corresponding set of regression tests -- in an effort to provide developers/users a mapping of the data files required for a given UFS Application-to-Physics Suite build as well as for a UFS application's given unique regression test.
#
# In this demontration, the tool will be applied against the UFS input and baseline datasets residing within the RDHPC platform, Orion.
#
# ### __Capabilities__
#
# The tool will be able to perform the following actions:
#
# - Apply feature engineering to obtain additional information regarding the data files.
#
# - Extract all data filenames mapping them to their corresponding relative directory path,
#   root folder, filename, filesize, file format, compiler (if applicable), CNTL folder (if applicable),
#   "input" or "restart" file type, resolution (km) category, resolution (C resolution) category.
#
# - Categorize & sort each data file into a given UFS Weather Model Application-to-Physics Suite build & Regression Tests.
#
# - Generate reference table/map of each data files to UFS Weather Model Application-to-Physics Suite & Regression Tests
#
# ### __Future Capabilities__
# - This tool can be used as a skeleton framework for querying information regarding the data files as they pertain to a unique UFS Weather Model Application-to-Physics Suite build &/or Regression Test.
#
# ### __Procedural Steps to Utilize Tool__
#
# #### ___Environment Setup___
#
# 1. Install miniconda on your machine. Note: Miniconda is a smaller version of Anaconda that only includes conda along with a small set of necessary and useful packages. With Miniconda, you can install only what you need, without all the extra packages that Anaconda comes packaged with:
#
# Download latest Miniconda (e.g. 3.9 version):
# - __wget https://repo.anaconda.com/miniconda/Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Check integrity downloaded file with SHA-256:
# - __sha256sum Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Reference SHA256 hash in following link: https://docs.conda.io/en/latest/miniconda.html
#
# Install Miniconda in Linux:
# - __bash Miniconda3-py39_4.9.2-Linux-x86_64.sh__
#
# Next, Miniconda installer will prompt where do you want to install Miniconda. Press ENTER to accept the default install location i.e. your $HOME directory. If you don't want to install in the default location, press CTRL+C to cancel the installation or mention an alternate installation directory. If you've chosen the default location, the installer will display “PREFIX=/var/home/<user>/miniconda3” and continue the installation.
#
# For installation to take into effect, run the following command:
# - __source ~/.bashrc__
#
# Next, you will see the prefix (base) in front of your terminal/shell prompt. Indicating the conda's base environment is activated.
#
# 2.	Once you have conda installed on your machine, perform the following to create a conda environment:
#
# To create a new environment (if a YAML file is not provided)
# - __conda create -n [Name of your conda environment you wish to create]__
#
# __(OR)__
#
# To ensure you are running Python 3.9:
# - __conda create -n myenv Python=3.9__
#
# __(OR)__
#
# To create a new environment from an existing YAML file (if a YAML file is provided):
# - __conda env create -f environment.yml__
#
# __*Note:__ A .yml file is a text file that contains a list of dependencies, which channels a list for installing dependencies for the given conda environment. For the code to utilize the dependencies, you will need to be in the directory where the environment.yml file lives.
#
# 4.	Activate the new environment via:
# - __conda activate [Name of your conda environment you wish to activate]__
#
# 5.	Verify that the new environment was installed correctly via:
# - __conda info --env__
#
# __*Note:__
#     - From this point on, must activate conda environment prior to .py script(s) or jupyter notebooks execution
# using the following command: __conda activate__
#     - To deactivate a conda environment:
#         - __conda deactivate__
#
# #### ___Link Home Directory to Dataset Location on RDHPCS Platform___
#
# 6.	Unfortunately, there is no way to navigate to the /work/ filesystem from within the Jupyter interface. The best way to workaround is to create a symbolic link in your home folder that will take you to the /work/ filesystem. Run the following command from a linux terminal on Orion to create the link:
#
# - __ln -s /work /home/[Your user account name]/work__
#
# Now, when you navigate to the /home/[Your user account name]/work directory in Jupyter, it will take you to the /work/ directory. Allowing you to obtain any data in the /work/ filesystem that you have permission to access from Jupyter. This same procedure will work for any filesystem available from the root directory.
#
# __*Note:__ On Orion, user must sym link from their home directory to the main directory containing the datasets of interest.
#
# #### ___Open & Run Data Analytics Tool on Jupyter Notebook___
#
# 7.	Open OnDemand has a built-in file explorer and file transfer application available directly from its dashboard via ...
#     - Login to https://orion-ood.hpc.msstate.edu/
#     - In the Open OnDemand Interface, select __Interactive Apps__ > __Jupyter Notbook__
#     - Set the following configurations to run Jupyter:
#
#
# #### ___Additonal Information___
#
# __To create a .yml file, execute the following commands:__
#
# - Activate the environment to export:
#     - __conda activate myenv__
#
# - Export your active environment to a new file:
#     - __conda env export > environment.yml__
#
#
# ### __Reference(s)__
# Latest UFS Weather Model Guide:
# - https://ufs-weather-model.readthedocs.io/en/latest/InputsOutputs.html

# %% [markdown]
# # Demo

# %%
if __name__ == '__main__':

    # Instantiate wrapper
    from script_scraper import ScriptScraper
    scraper_wrapper = ScriptScraper(local_repo_folder = 'ufs-wm-repo-033022')

    # Read referencing script.
    appsphys2test_txt = scraper_wrapper.read_appsphys2test()
    #rtconf_txt = scraper_wrapper.read_script()

    # Generate dictonary of app-to-physics_suite to test name.
    appsphys2test_dict = scraper_wrapper.convert_list2dict(appsphys2test_txt)
    appsphys2test_dict = scraper_wrapper.get_app2test(appsphys2test_dict)
    scraper_wrapper.get_rtinfo(appsphys2test_dict)

    # # Read files within /fv3_conf & /parm & /tests
    raw_data_dict = scraper_wrapper.read_raw_filenames()
    input_data_dict = scraper_wrapper.read_tests_fv3_parms(prefix_list=['cp', 'mv', 'rsync', 'ln'])

    # Generate associating app-to-physics suite to their corresponding test parameters, fv3_conf filename, & parm filename.
    appsphys2test_dict = scraper_wrapper.get_appsphys2testparams(appsphys2test_dict.copy(), input_data_dict)

    # Convert dictionary to dataframe & save as pickle.
    appsphys2test_df = scraper_wrapper.convert_dict2df(appsphys2test_dict)

    # Unique global variables of entire fv3_conf files corpus
    unique_vars_fv3conf = scraper_wrapper.get_unique_vars(input_data_dict, filetype ='fv3_conf')
# Out:
# Total unique UFS App-to-Physics Suite builds:
#  35
#
# Total number of tests (if performing tests for all UFS App-to-Physics Suite builds):
#  604
#
# Total unique tests overall (per current rt.conf):
#  118
#
# List of unique tests present (per current rt.conf):
#  {'hafs_regional_atm', 'control_fhzero', 'rap_unified_drag_suite_debug', 'cpld_restart_c384_p8', 'hafs_regional_atm_thompson_gfdlsf', 'datm_cdeps_mx025_gefs', 'control_wam', 'cpld_decomp_p8', 'hrrr_control', 'rap_control', 'datm_cdeps_control_gefs', 'rap_restart', 'control_stochy_debug', 'control_thompson_debug', 'regional_netcdf_parallel', 'control_rrtmgp_2threads', 'rap_decomp', 'rap_2threads', 'cpld_restart_c96_p8', 'hafs_regional_telescopic_2nests_atm', 'datm_cdeps_control_cfsr', 'rap_sfcdiff', 'rap_diag_debug', 'rap_control_debug', 'datm_cdeps_3072x1536_cfsr', 'cpld_mpi_p8', 'control_2threads', 'cpld_restart_c192_p8', 'cpld_control_c96_p8', 'rap_sfcdiff_debug', 'regional_noquilt', 'hafs_regional_1nest_atm', 'datm_cdeps_bulk_cfsr', 'control_latlon', 'control_restart', 'cpld_2threads_p8', 'rap_noah_debug', 'control_stochy', 'control_csawmgt_debug', 'hafs_regional_atm_ocn_wav', 'datm_cdeps_debug_cfsr', 'hafs_regional_docn_oisst', 'regional_hafs', 'datm_cdeps_restart_cfsr', 'control_thompson', 'control_debug_p8', 'regional_RRTMGP', 'cpld_debug_p8', 'cpld_control_p7_rrtmgp', 'control_restart_p8', 'control_c192', 'hafs_regional_atm_ocn', 'control_ras_debug', 'control_rrtmgp', 'rap_flake_debug', 'rap_cires_ugwp_debug', 'control_p8', 'control_lndp', 'control_c48', 'regional_2threads', 'datm_cdeps_mx025_cfsr', 'control_thompson_extdiag_debug', 'cpld_control_c384_p8', 'control_lndp_debug', 'control_decomp_p8', 'rap_rrtmgp_debug', 'control_atm_aerosols', 'control_thompson_no_aero_debug', 'hafs_regional_datm_cdeps', 'hafs_regional_atm_wav', 'rap_noah_sfcdiff_cires_ugwp_debug', 'control_c384', 'rrfs_conus13km_hrrr_warm', 'regional_debug', 'cpld_bmark_p7', 'cpld_control_c192_p8', 'control_csawmg_debug', 'rap_unified_ugwp_debug', 'rrfs_v1beta_debug', 'hafs_regional_docn', 'datm_cdeps_bulk_gefs', 'control_stochy_restart', 'control_wrtGauss_netcdf_parallel_debug', 'hafs_global_1nest_atm', 'datm_cdeps_stochy_gefs', 'control_debug', 'rap_sfcdiff_restart', 'rap_lndp_debug', 'control', 'regional_control', 'datm_cdeps_multiple_files_cfsr', 'hafs_global_multiple_4nests_atm', 'control_csawmgt', 'control_2threads_debug', 'cpld_bmark_p8', 'regional_restart', 'rap_sfcdiff_decomp', 'control_CubedSphereGrid', 'control_rrtmgp_debug', 'control_atmwav', 'control_decomp', 'control_csawmg', 'control_2threads_p8', 'control_c768', 'control_wam_debug', 'control_thompson_no_aero', 'control_diag_debug', 'control_rrtmgp_c192', 'control_wrtGauss_netcdf_parallel', 'control_ras', 'control_flake', 'control_c384gdas_wav', 'rrfs_v1beta', 'control_p7_rrtmgp', 'control_c384gdas', 'cpld_control_p8', 'rrfs_conus13km_radar_tten_warm', 'control_CubedSphereGrid_debug'}
#
# Total unique categories (UFS App-to-Physics Suite builds to Test_Type):
#  50

# %% [markdown]
# # Demo: Dictionary of source-to-destination paths of data files being copied, linked, moved, or synced per fv3_conf.
# Majority of fv3_conf listed file paths is defined by global variable. These global variables are set within the following scripts:
#
# - __/ufs-weather-model-develop/ufs-weather-model-develop/default_vars.sh__
#     - Within a unique 'default_vars.sh' method, there is a unique set of exported variables. => Table: Unique 'default_vars.sh' method-to-exported variables
#
#     - Some of the exported variables are set by variables dependent on the 'MACHINE_ID' utilized by a user (listed at beginning of 'default.sh') => Table: Machine-to-Machine dependent variables
#
#     - Each unique test will call a unique method in 'default_vars.sh' & overwrite some of those default variables in its '/tests file'. => Table: '/tests file'-to-overwriting default variables
#
# For simplicity in the preliminary stage of ingesting data for performing regression tests, once data is allocated in an established cloud bucket (k-v object store) the fv3_conf files for th latest UFS weather model release version will be altered to incorporate the s3.boto to download files from the bucket. The input_data_dict['fv3_conf'] will be used as a reference to call the cloud data files by the data files' key.

# %%
# Test parameters set per /tests file.
input_data_dict['tests']

# Data files mentioned per /fv3_conf file.
#input_data_dict['fv3_conf']

# Data files mentioned per /parm file.
#input_data_dict['parm']
# Out:
# defaultdict(dict,
#             {'cpld_control_p7_rrtmgp': {'CNTL_DIR': 'cpld_control_p7_rrtmgp',
#               'RESTART_N': '12',
#               'RESTART_INTERVAL': '${RESTART_N} -1',
#               'eps_imesh': '2.5e-1',
#               'USE_CICE_ALB': '.false.',
#               'MIN_SEAICE': '1.0e-11',
#               'IOPT_SFC': '1',
#               'DNATS': '1',
#               'FIELD_TABLE': 'field_table_gfsv16',
#               'KNOB_UGWP_VERSION': '1',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V1': '.true.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'FSICL': '99999',
#               'FSICS': '99999',
#               'CDMBWD': "'1.0,2.2,1.0,1.0'",
#               'DIAG_TABLE': 'diag_table_template',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'DO_RRTMGP': '.true.',
#               'CCPP_SUITE': 'FV3_GFS_v16_coupled_p7_rrtmgp',
#               'INPUT_NML': 'cpld_control_rrtmgp.nml.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'cpld_control_p8': {'CNTL_DIR': 'cpld_control_p8',
#               'RESTART_N': '12',
#               'RESTART_INTERVAL': '${RESTART_N} -1',
#               'OUTPUT_FH': "'0 21 24'",
#               'CPLCHM': '.true.',
#               'NEMS_CONFIGURE': 'nems.configure.cpld_aero_wave.IN',
#               'FIELD_TABLE': 'field_table_thompson_noaero_tke_GOCART',
#               'eps_imesh': '2.5e-1',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'control_latlon': {'CNTL_DIR': 'control_latlon',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'global_latlon'",
#               'IMO': '360',
#               'JMO': '181',
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'IOVR': '3',
#               'OUTPUT_FH': "'0 24'",
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'control_wrtGauss_netcdf_parallel': {'CNTL_DIR': 'control_wrtGauss_netcdf_parallel',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'IOVR': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf_parallel'",
#               'IDEFLATE': '1',
#               'NBITS': '14',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'cpld_bmark_p7': {'CNTL_DIR': 'cpld_bmark_p7',
#               'SYEAR': '2013',
#               'SMONTH': '04',
#               'SDAY': '01',
#               'SHOUR': '00',
#               'SECS': '`expr $SHOUR \\* 3600`',
#               'BMIC': '.true.',
#               'DAYS': '0.25',
#               'FHMAX': '6',
#               'RESTART_N': '`expr ${FHMAX} - ${FHROT}`',
#               'RESTART_INTERVAL': '${RESTART_N} -1',
#               'TASKS': '$TASKS_cpl_bmrk',
#               'TPN': '$TPN_cpl_bmrk',
#               'INPES': '$INPES_cpl_bmrk',
#               'JNPES': '$JNPES_cpl_bmrk',
#               'THRD': '$THRD_cpl_bmrk',
#               'WRTTASK_PER_GROUP': '$WPG_cpl_bmrk',
#               'med_petlist_bounds': '$MPB_cpl_bmrk',
#               'atm_petlist_bounds': '$APB_cpl_bmrk',
#               'ocn_petlist_bounds': '$OPB_cpl_bmrk',
#               'ice_petlist_bounds': '$IPB_cpl_bmrk',
#               'wav_petlist_bounds': '$WPB_cpl_bmrk',
#               'ATMRES': 'C384',
#               'NPX': '385',
#               'NPY': '385',
#               'IMO': '1536',
#               'JMO': '768',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'ATMTILESIZE': '`expr $NPX - 1`',
#               'OCNRES': '025',
#               'ICERES': '0.25',
#               'NX_GLB': '1440',
#               'NY_GLB': '1080',
#               'NPROC_ICE': '$NPROC_ICE_cpl_bmrk',
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'DT_ATMOS': '300',
#               'DT_CICE': '${DT_ATMOS}',
#               'DT_DYNAM_MOM6': '900',
#               'DT_THERM_MOM6': '1800',
#               'NEMS_CONFIGURE': 'nems.configure.cpld_wave.IN',
#               'coupling_interval_slow_sec': '${DT_THERM_MOM6}',
#               'coupling_interval_fast_sec': '${DT_ATMOS}',
#               'MOM_INPUT': 'MOM_input_template_${OCNRES}',
#               'MESHOCN_ICE': 'mesh.mx${OCNRES}.nc',
#               'CICEGRID': 'grid_cice_NEMS_mx${OCNRES}.nc',
#               'CICEMASK': 'kmtu_cice_NEMS_mx${OCNRES}.nc',
#               'CHLCLIM': 'seawifs-clim-1997-2010.${NX_GLB}x${NY_GLB}.v20180328.nc',
#               'FRUNOFF': 'runoff.daitren.clim.${NX_GLB}x${NY_GLB}.v20180328.nc',
#               'FNALBC': "'C384.snowfree_albedo.tileX.nc'",
#               'FNALBC2': "'C384.facsf.tileX.nc'",
#               'FNTG3C': "'C384.substrate_temperature.tileX.nc'",
#               'FNVEGC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNVETC': "'C384.vegetation_type.tileX.nc'",
#               'FNSOTC': "'C384.soil_type.tileX.nc'",
#               'FNVMNC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNVMXC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNSLPC': "'C384.slope_type.tileX.nc'",
#               'FNABSC': "'C384.maximum_snow_albedo.tileX.nc'",
#               'MOM6_RIVER_RUNOFF': 'True',
#               'MOM6_RESTART_SETTING': 'r',
#               'USE_CICE_ALB': '.false.',
#               'MIN_SEAICE': '1.0e-11',
#               'IOPT_SFC': '1',
#               'DNATS': '1',
#               'IMP_PHYSICS': '11',
#               'CCPP_SUITE': 'FV3_GFS_v16_coupled_nsstNoahmpUGWPv1',
#               'FIELD_TABLE': 'field_table_gfsv16',
#               'LGFDLMPRAD': '.true.',
#               'KNOB_UGWP_VERSION': '1',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V1': '.true.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'FSICL': '99999',
#               'FSICS': '99999',
#               'DO_SAT_ADJ': '.true.',
#               'CDMBWD': "'1.0,2.2,1.0,1.0'",
#               'DZ_MIN': '2',
#               'WRITE_NSFLIP': '.false.',
#               'FV3BMIC': "'gfs_p7'",
#               'WW3GRIDLINE': "'gwes_30m' 'no' 'CPL:native' 'CPL:native' 'CPL:native' 'no' 'no' 'no' 'no' 'no'  1  1  0.00 1.00  F",
#               'WW3RSTDTHR': '${FHMAX}',
#               'DT_2_RST': '$(printf %02d $(( ${WW3RSTDTHR}*3600 )))',
#               'RUN_BEG': '${SYEAR}${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'RUN_END': '2100${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'OUT_BEG': '$RUN_BEG',
#               'OUT_END': '$RUN_END',
#               'RST_BEG': '$RUN_BEG',
#               'RST_2_BEG': '$RUN_BEG',
#               'RST_END': '$RUN_END',
#               'RST_2_END': '$RUN_END',
#               'DIAG_TABLE': 'diag_table_template',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'INPUT_NML': 'cpld_control_p7.nml.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'rap_control_debug': {'CNTL_DIR': 'rap_control_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '300',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'FHMAX': '1',
#               'OUTPUT_FH': '0 1',
#               '#WRITE_DOPOST': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_RAP',
#               'INPUT_NML': 'rap.nml.IN',
#               'FIELD_TABLE': 'field_table_thompson_aero_tke',
#               'NEW_DIAGTABLE': 'diag_table_rap',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'LTAEROSOL': '.true.',
#               'IALB': '2',
#               'IEMS': '2',
#               'HYBEDMF': '.false.',
#               'DO_MYNNEDMF': '.true.',
#               'DO_MYNNSFCLAY': '.true.',
#               'IMFSHALCNV': '3',
#               'IMFDEEPCNV': '3',
#               'LSM': '3',
#               'LSOIL_LSM': '9',
#               'KICE': '9',
#               'GWD_OPT': '3',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V0_OROG_ONLY': '.false.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1': '.false.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'Test Info': ['export_fv3']},
#              'rap_2threads': {'CNTL_DIR': 'rap_control',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '300',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': '12 -1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'OUTPUT_FH': "'0 21 24'",
#               'THRD': '2',
#               'TASKS': '$TASKS_thrd',
#               'TPN': '$TPN_thrd',
#               'INPES': '$INPES_thrd',
#               'JNPES': '$JNPES_thrd',
#               'WRTTASK_PER_GROUP': '6',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_RAP',
#               'INPUT_NML': 'rap.nml.IN',
#               'FIELD_TABLE': 'field_table_thompson_aero_tke',
#               'NEW_DIAGTABLE': 'diag_table_rap',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'LTAEROSOL': '.true.',
#               'IALB': '2',
#               'IEMS': '2',
#               'HYBEDMF': '.false.',
#               'DO_MYNNEDMF': '.true.',
#               'DO_MYNNSFCLAY': '.true.',
#               'IMFSHALCNV': '3',
#               'IMFDEEPCNV': '3',
#               'LSM': '3',
#               'LSOIL_LSM': '9',
#               'KICE': '9',
#               'GWD_OPT': '3',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V0_OROG_ONLY': '.false.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1': '.false.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'Test Info': ['export_fv3']},
#              'control_thompson_no_aero_debug': {'CNTL_DIR': 'control_thompson_no_aero_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '600',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'FHMAX': '1',
#               'OUTPUT_FH': '0 1',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'NSRADAR_RESET': '3600.0',
#               'LTAEROSOL': '.false.',
#               'HYBEDMF': '.false.',
#               'SATMEDMF': '.true.',
#               'DO_MYNNEDMF': '.false.',
#               'IMFSHALCNV': '2',
#               'IMFDEEPCNV': '2',
#               'IAER': '5111',
#               'ICLIQ_SW': '2',
#               'IOVR': '3',
#               'LHEATSTRG': '.true.',
#               'DO_TOFD': '.T',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_thompson',
#               'INPUT_NML': 'control_thompson.nml.IN',
#               'FIELD_TABLE': 'field_table_thompson_noaero_tke',
#               'Test Info': ['export_fv3']},
#              'control_restart_p8': {'CNTL_DIR': 'control_p8',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'WRITE_DOPOST': '.true.',
#               'FHROT': '12',
#               'RESTART_FILE_PREFIX': '${SYEAR}${SMONTH}${SDAY}.$(printf %02d $(( ${SHOUR} + ${FHROT}  )))0000',
#               'WARM_START': '.true.',
#               'NGGPS_IC': '.false.',
#               'EXTERNAL_IC': '.false.',
#               'MAKE_NH': '.false.',
#               'MOUNTAIN': '.true.',
#               'NA_INIT': '0',
#               'IALB': '2',
#               'IEMS': '2',
#               'LSM': '2',
#               'IOPT_DVEG': '4',
#               'IOPT_CRS': '2',
#               'IOPT_RAD': '3',
#               'IOPT_ALB': '1',
#               'IOPT_STC': '3',
#               'IOPT_SFC': '3',
#               'D2_BG_K1': '0.20',
#               'D2_BG_K2': '0.04',
#               'PSM_BC': '1',
#               'DDDMP': '0.1',
#               'USE_MERRA2': '.true.',
#               'IAER': '1011',
#               'NSTF_NAME': '2,0,0,0,0',
#               'LHEATSTRG': '.true.',
#               'LSEASPRAY': '.true.',
#               'GWD_OPT': '2',
#               'DO_UGWP_V1': '.false.',
#               'KNOB_UGWP_VERSION': '0',
#               'KNOB_UGWP_NSLOPE': '1',
#               'DO_UGWP_V0': '.true.',
#               'DO_GSL_DRAG_LS_BL': '.false.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'DO_UGWP_V0_NST_ONLY': '.false.',
#               'LDIAG_UGWP': '.false.',
#               'DO_CA': '.true.',
#               'CA_SGS': '.true.',
#               'CA_GLOBAL': '.false.',
#               'NCA': '1',
#               'NCELLS': '5',
#               'NLIVES': '12',
#               'NTHRESH': '18',
#               'NSEED': '1',
#               'NFRACSEED': '0.5',
#               'CA_TRIGGER': '.true.',
#               'NSPINUP': '1',
#               'ISEED_CA': '12345',
#               'TILEDFIX': '.true.',
#               'FNALBC': "'C96.snowfree_albedo.tileX.nc'",
#               'FNALBC2': "'C96.facsf.tileX.nc'",
#               'FNTG3C': "'C96.substrate_temperature.tileX.nc'",
#               'FNVEGC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNVETC': "'C96.vegetation_type.tileX.nc'",
#               'FNSOTC': "'C96.soil_type.tileX.nc'",
#               'FNSMCC': '${FNSMCC_control}',
#               'FNMSKH': '${FNMSKH_control}',
#               'FNVMNC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNVMXC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNSLPC': "'C96.slope_type.tileX.nc'",
#               'FNABSC': "'C96.maximum_snow_albedo.tileX.nc'",
#               'LANDICE': '.false.',
#               'FSICL': '0',
#               'FSICS': '0',
#               'IMP_PHYSICS': '8',
#               'LGFDLMPRAD': '.false.',
#               'DO_SAT_ADJ': '.false.',
#               'DNATS': '2',
#               'DZ_MIN': '6',
#               'MIN_SEAICE': '0.15',
#               'FRAC_GRID': '.true.',
#               'MOM6_RESTART_SETTING': 'n',
#               'USE_CICE_ALB': '.false.',
#               'WRITE_NSFLIP': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v17_p8',
#               'FIELD_TABLE': 'field_table_thompson_noaero_tke',
#               'DIAG_TABLE': 'diag_table_gfsv16_merra2',
#               'INPUT_NML': 'cpld_control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'datm_cdeps_bulk_cfsr': {'CNTL_DIR': 'datm_cdeps_bulk_cfsr',
#               'DATM_SRC': 'CFSR',
#               'FILENAME_BASE': "'cfsr.'",
#               'IATM': '1760',
#               'JATM': '880',
#               'RESTART_N': '12',
#               'flux_scheme': "'-1'",
#               'eps_imesh': "'2.5e-1'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'hafs_global_1nest_atm': {'CNTL_DIR': 'hafs_global_1nest_atm',
#               'HAFS': 'true',
#               'FHMAX': '6',
#               'RESTART_N': '${FHMAX}',
#               'TASKS': '240',
#               'THRD': '2',
#               'TPN': '$TPN_thrd',
#               'DT_ATMOS': '90',
#               'IDEFLATE': '1',
#               'NFHMAX_HF': '-1',
#               'NFHOUT_HF': '3',
#               'NFHOUT': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf'",
#               'SDAY': '25',
#               'SHOUR': '12',
#               'SMONTH': '08',
#               'SYEAR': '2020',
#               'WRTTASK_PER_GROUP': '60',
#               'OUTPUT_GRID': "'global_latlon'",
#               'IMO': '360',
#               'JMO': '181',
#               'OUTPUT_GRID_2': "'rotated_latlon'",
#               'CEN_LON_2': '-86.0',
#               'CEN_LAT_2': '23.0',
#               'LON1_2': '-45.00',
#               'LAT1_2': '-40.00',
#               'LON2_2': '45.00',
#               'LAT2_2': '40.00',
#               'DLON_2': '0.25',
#               'DLAT_2': '0.25',
#               'BLOCKSIZE': '${BLOCKSIZE:-24}',
#               'CCPP_SUITE': 'FV3_HAFS_v0_gfdlmp_tedmf',
#               'DEFLATE_LEVEL': '-1',
#               'INPES': '4',
#               'JNPES': '5',
#               'NPX': '97',
#               'NPY': '97',
#               'NPZ': '64',
#               'NPZP': '$(($NPZ + 1))',
#               'K_SPLIT': '4',
#               'N_SPLIT': '5',
#               'NWAT': '6',
#               'NA_INIT': '1',
#               'EXTERNAL_IC': '.true.',
#               'NGGPS_IC': '.true.',
#               'MOUNTAIN': '.false.',
#               'WARM_START': '.false.',
#               'TARGET_LAT': '23.0',
#               'TARGET_LON': '-86.0',
#               'STRETCH_FAC': '1.0001',
#               'FULL_ZS_FILTER': '.false.',
#               'N_ZS_FILTER': '0',
#               'GRID_PES': '120,60',
#               'TILE_COARSE': '0,6',
#               'NUM_TILE_TOP': '6',
#               'NEST_REFINE': '0,3',
#               'NEST_IOFFSETS': '1,9',
#               'NEST_JOFFSETS': '1,9',
#               'FHCYC': '0',
#               'FHSWR': '1800',
#               'FHLWR': '1800',
#               'NSTF_NAME': '2,0,0,0,0',
#               'CPLFLX': '.false.',
#               'CPLOCN2ATM': '.true.',
#               'CPLWAV': '.false.',
#               'CPLWAV2ATM': '.false.',
#               'CPL_IMP_MRG': '.false.',
#               'INPES_NEST02': '6',
#               'JNPES_NEST02': '10',
#               'NPX_NEST02': '241',
#               'NPY_NEST02': '241',
#               'K_SPLIT_NEST02': '4',
#               'N_SPLIT_NEST02': '5',
#               'NESTED': '.true.',
#               'CMEPS': 'false',
#               'RUNTYPE': 'startup',
#               'USE_COLDSTART': 'false',
#               'FIELD_TABLE': 'field_table_hafs',
#               'DIAG_TABLE': 'diag_table_hafs_template',
#               'INPUT_NML': 'input_global_hafs.nml.IN',
#               'INPUT_NEST02_NML': 'input_nest_hafs.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_hafs_shared.IN',
#               'NEMS_CONFIGURE': 'nems.configure.hafs_atm.IN',
#               'FV3_RUN': 'hafs_fv3_run.IN',
#               'Test Info': ['export_fv3', 'export_hafs']},
#              'datm_cdeps_mx025_gefs': {'CNTL_DIR': 'datm_cdeps_mx025_gefs',
#               'atm_datamode': 'GEFS',
#               'DAYS': '0.5',
#               'FHMAX': '12',
#               'RESTART_N': '${FHMAX}',
#               'DT_DYNAM_MOM6': "'900'",
#               'DT_THERM_MOM6': "'1800'",
#               'IATM': '1536',
#               'JATM': '768',
#               'ATM_NX_GLB': '$IATM',
#               'ATM_NY_GLB': '$JATM',
#               'ATMRES': "'1536x768'",
#               'DATM_SRC': 'GEFS',
#               'FILENAME_BASE': "'gefs.'",
#               'mesh_file': 'gefs_mesh.nc',
#               'MESH_ATM': 'DATM_INPUT/${mesh_file}',
#               'stream_files': 'DATM_INPUT/${FILENAME_BASE}201110.nc',
#               'TASKS': '$TASKS_cdeps_025',
#               'TPN': '$TPN_cdeps_025',
#               'atm_petlist_bounds': '$APB_cdeps_025',
#               'med_petlist_bounds': '$MPB_cdeps_025',
#               'ocn_petlist_bounds': '$OPB_cdeps_025',
#               'ice_petlist_bounds': '$IPB_cdeps_025',
#               'OCNRES': "'025'",
#               'ICERES': "'0.25'",
#               'NX_GLB': '1440',
#               'NY_GLB': '1080',
#               'NPROC_ICE': "'48'",
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'MOM_INPUT': 'MOM_input_template_${OCNRES}',
#               'MESHOCN_ICE': 'mesh.mx${OCNRES}.nc',
#               'CICEGRID': 'grid_cice_NEMS_mx${OCNRES}.nc',
#               'CICEMASK': 'kmtu_cice_NEMS_mx${OCNRES}.nc',
#               'CHLCLIM': "'seawifs-clim-1997-2010.1440x1080.v20180328.nc'",
#               'MOM6_RIVER_RUNOFF': "'True'",
#               'FRUNOFF': 'runoff.daitren.clim.1440x1080.v20180328.nc',
#               'MOM6_RESTART_SETTING': "'r'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'datm_cdeps_stochy_gefs': {'CNTL_DIR': 'datm_cdeps_stochy_gefs',
#               'atm_datamode': 'GEFS',
#               'IATM': '1536',
#               'JATM': '768',
#               'ATM_NX_GLB': '$IATM',
#               'ATM_NY_GLB': '$JATM',
#               'ATMRES': "'1536x768'",
#               'DATM_SRC': 'GEFS',
#               'FILENAME_BASE': "'gefs.'",
#               'mesh_file': 'gefs_mesh.nc',
#               'MESH_ATM': 'DATM_INPUT/${mesh_file}',
#               'stream_files': 'DATM_INPUT/${FILENAME_BASE}201110.nc',
#               'RESTART_N': '12',
#               'eps_imesh': "'2.5e-1'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'DO_OCN_SPPT': 'True',
#               'PERT_EPBL': 'True',
#               'OCN_SPPT': '1.0',
#               'EPBL': '1.0',
#               'Test Info': ['export_datm_cdeps']},
#              'rap_control': {'CNTL_DIR': 'rap_control',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '300',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': '12 -1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'OUTPUT_FH': "'0 21 24'",
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_RAP',
#               'INPUT_NML': 'rap.nml.IN',
#               'FIELD_TABLE': 'field_table_thompson_aero_tke',
#               'NEW_DIAGTABLE': 'diag_table_rap',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'LTAEROSOL': '.true.',
#               'IALB': '2',
#               'IEMS': '2',
#               'HYBEDMF': '.false.',
#               'DO_MYNNEDMF': '.true.',
#               'DO_MYNNSFCLAY': '.true.',
#               'IMFSHALCNV': '3',
#               'IMFDEEPCNV': '3',
#               'LSM': '3',
#               'LSOIL_LSM': '9',
#               'KICE': '9',
#               'GWD_OPT': '3',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V0_OROG_ONLY': '.false.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1': '.false.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'Test Info': ['export_fv3']},
#              'control_thompson_extdiag_debug': {'CNTL_DIR': 'control_thompson_debug_extdiag',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '600',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'FHMAX': '1',
#               'OUTPUT_FH': '0 1',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'LTAEROSOL': '.true.',
#               'EXT_DIAG_THOMPSON': '.true.',
#               'HYBEDMF': '.false.',
#               'SATMEDMF': '.true.',
#               'DO_MYNNEDMF': '.false.',
#               'IMFSHALCNV': '2',
#               'IMFDEEPCNV': '2',
#               'IAER': '5111',
#               'ICLIQ_SW': '2',
#               'IOVR': '3',
#               'LHEATSTRG': '.true.',
#               'DO_TOFD': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_thompson',
#               'INPUT_NML': 'control_thompson.nml.IN',
#               'DIAG_TABLE': "'diag_table_gfsv16_thompson_extdiag'",
#               'FIELD_TABLE': 'field_table_thompson_aero_tke',
#               'Test Info': ['export_fv3']},
#              'control_decomp_p8': {'CNTL_DIR': 'control_p8',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': '0',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'WRITE_DOPOST': '.true.',
#               'OUTPUT_FH': "'0 21 24'",
#               'INPES': '6',
#               'JNPES': '4',
#               'IALB': '2',
#               'IEMS': '2',
#               'LSM': '2',
#               'IOPT_DVEG': '4',
#               'IOPT_CRS': '2',
#               'IOPT_RAD': '3',
#               'IOPT_ALB': '1',
#               'IOPT_STC': '3',
#               'IOPT_SFC': '3',
#               'D2_BG_K1': '0.20',
#               'D2_BG_K2': '0.04',
#               'PSM_BC': '1',
#               'DDDMP': '0.1',
#               'USE_MERRA2': '.true.',
#               'IAER': '1011',
#               'NSTF_NAME': '2,1,0,0,0',
#               'LHEATSTRG': '.true.',
#               'LSEASPRAY': '.true.',
#               'GWD_OPT': '2',
#               'DO_UGWP_V1': '.false.',
#               'KNOB_UGWP_VERSION': '0',
#               'KNOB_UGWP_NSLOPE': '1',
#               'DO_UGWP_V0': '.true.',
#               'DO_GSL_DRAG_LS_BL': '.false.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'DO_UGWP_V0_NST_ONLY': '.false.',
#               'LDIAG_UGWP': '.false.',
#               'DO_CA': '.true.',
#               'CA_SGS': '.true.',
#               'CA_GLOBAL': '.false.',
#               'NCA': '1',
#               'NCELLS': '5',
#               'NLIVES': '12',
#               'NTHRESH': '18',
#               'NSEED': '1',
#               'NFRACSEED': '0.5',
#               'CA_TRIGGER': '.true.',
#               'NSPINUP': '1',
#               'ISEED_CA': '12345',
#               'TILEDFIX': '.true.',
#               'FNALBC': "'C96.snowfree_albedo.tileX.nc'",
#               'FNALBC2': "'C96.facsf.tileX.nc'",
#               'FNTG3C': "'C96.substrate_temperature.tileX.nc'",
#               'FNVEGC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNVETC': "'C96.vegetation_type.tileX.nc'",
#               'FNSOTC': "'C96.soil_type.tileX.nc'",
#               'FNSMCC': '${FNSMCC_control}',
#               'FNMSKH': '${FNMSKH_control}',
#               'FNVMNC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNVMXC': "'C96.vegetation_greenness.tileX.nc'",
#               'FNSLPC': "'C96.slope_type.tileX.nc'",
#               'FNABSC': "'C96.maximum_snow_albedo.tileX.nc'",
#               'LANDICE': '.false.',
#               'FSICL': '0',
#               'FSICS': '0',
#               'IMP_PHYSICS': '8',
#               'LGFDLMPRAD': '.false.',
#               'DO_SAT_ADJ': '.false.',
#               'DNATS': '2',
#               'DZ_MIN': '6',
#               'MIN_SEAICE': '0.15',
#               'FRAC_GRID': '.true.',
#               'MOM6_RESTART_SETTING': 'n',
#               'USE_CICE_ALB': '.false.',
#               'WRITE_NSFLIP': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v17_p8',
#               'FIELD_TABLE': 'field_table_thompson_noaero_tke',
#               'DIAG_TABLE': 'diag_table_gfsv16_merra2',
#               'INPUT_NML': 'cpld_control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'cpld_restart_c96_p8': {'CNTL_DIR': 'cpld_control_c96_p8',
#               'FHROT': '12',
#               'RESTART_N': '$((FHMAX-$FHROT))',
#               'RESTART_FILE_PREFIX': '${SYEAR}${SMONTH}${SDAY}.$(printf %02d $(( ${FHROT} + ${SHOUR} )))0000',
#               'RESTART_FILE_SUFFIX_HRS': '${SYEAR}-${SMONTH}-${SDAY}-$(printf %02d $(( ${FHROT} + ${SHOUR})))',
#               'RESTART_FILE_SUFFIX_SECS': '${SYEAR}-${SMONTH}-${SDAY}-$(printf %02d $(( (${FHROT}+ ${SHOUR})*3600 )))',
#               'WARM_START': '.true.',
#               'MAKE_NH': '.false.',
#               'NA_INIT': '0',
#               'EXTERNAL_IC': '.false.',
#               'NGGPS_IC': '.false.',
#               'MOUNTAIN': '.true.',
#               'NSTF_NAME': '2,0,0,0,0',
#               'CICERUNTYPE': 'continue',
#               'RUNTYPE': 'continue',
#               'USE_RESTART_TIME': '.true.',
#               'MOM6_RESTART_SETTING': 'r',
#               'TASKS': '$TASKS_cpl_c96',
#               'TPN': '$TPN_cpl_c96',
#               'INPES': '$INPES_cpl_c96',
#               'JNPES': '$JNPES_cpl_c96',
#               'THRD': '$THRD_cpl_c96',
#               'WRTTASK_PER_GROUP': '$WPG_cpl_c96',
#               'NPROC_ICE': '$NPROC_ICE_cpl_c96',
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'med_petlist_bounds': '$MPB_cpl_c96',
#               'atm_petlist_bounds': '$APB_cpl_c96',
#               'chm_petlist_bounds': '$CHM_cpl_c96',
#               'ocn_petlist_bounds': '$OPB_cpl_c96',
#               'ice_petlist_bounds': '$IPB_cpl_c96',
#               'CPLWAV': '.false.',
#               'CPLWAV2ATM': '.false.',
#               'MOM6_USE_WAVES': 'False',
#               'eps_imesh': '2.5e-1',
#               'CPLCHM': '.true.',
#               'NEMS_CONFIGURE': 'nems.configure.cpld_aero.IN',
#               'FIELD_TABLE': 'field_table_thompson_noaero_tke_GOCART',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'control_rrtmgp_debug': {'CNTL_DIR': 'control_rrtmgp_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'FHMAX': '1',
#               'OUTPUT_FH': '0 1',
#               'DO_RRTMGP': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_RRTMGP',
#               'INPUT_NML': 'control_rrtmgp.nml.IN',
#               'Test Info': ['export_fv3']},
#              'datm_cdeps_mx025_cfsr': {'CNTL_DIR': 'datm_cdeps_mx025_cfsr',
#               'DATM_SRC': 'CFSR',
#               'FILENAME_BASE': "'cfsr.'",
#               'IATM': '1760',
#               'JATM': '880',
#               'DAYS': '0.5',
#               'FHMAX': '12',
#               'RESTART_N': '${FHMAX}',
#               'DT_DYNAM_MOM6': "'900'",
#               'DT_THERM_MOM6': "'1800'",
#               'TASKS': '$TASKS_cdeps_025',
#               'TPN': '$TPN_cdeps_025',
#               'atm_petlist_bounds': '$APB_cdeps_025',
#               'med_petlist_bounds': '$MPB_cdeps_025',
#               'ocn_petlist_bounds': '$OPB_cdeps_025',
#               'ice_petlist_bounds': '$IPB_cdeps_025',
#               'OCNRES': "'025'",
#               'ICERES': "'0.25'",
#               'NX_GLB': '1440',
#               'NY_GLB': '1080',
#               'NPROC_ICE': "'48'",
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'MOM_INPUT': 'MOM_input_template_${OCNRES}',
#               'MESHOCN_ICE': 'mesh.mx${OCNRES}.nc',
#               'CICEGRID': 'grid_cice_NEMS_mx${OCNRES}.nc',
#               'CICEMASK': 'kmtu_cice_NEMS_mx${OCNRES}.nc',
#               'CHLCLIM': "'seawifs-clim-1997-2010.1440x1080.v20180328.nc'",
#               'MOM6_RIVER_RUNOFF': "'True'",
#               'FRUNOFF': 'runoff.daitren.clim.1440x1080.v20180328.nc',
#               'MOM6_RESTART_SETTING': "'r'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'datm_cdeps_multiple_files_cfsr': {'CNTL_DIR': 'datm_cdeps_control_cfsr',
#               'DATM_SRC': 'CFSR',
#               'FILENAME_BASE': "'cfsr.'",
#               'IATM': '1760',
#               'JATM': '880',
#               'RESTART_N': '12',
#               'stream_files': 'DATM_INPUT/cfsr.2011100100.nc DATM_INPUT/cfsr.2011100106.nc DATM_INPUT/cfsr.2011100112.nc DATM_INPUT/cfsr.2011100118.nc DATM_INPUT/cfsr.2011100200.nc DATM_INPUT/cfsr.2011100206.nc',
#               'eps_imesh': "'2.5e-1'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'control_CubedSphereGrid': {'CNTL_DIR': 'control_CubedSphereGrid',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': '0',
#               'OUTPUT_GRID': "'cubed_sphere_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'IOVR': '3',
#               'WRITE_DOPOST': '.false.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_fhout.IN',
#               'Test Info': ['export_fv3']},
#              'control_flake': {'CNTL_DIR': 'control_flake',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'DO_SPPT': '.true.',
#               'DO_SHUM': '.true.',
#               'DO_SKEB': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_flake',
#               'INPUT_NML': 'control_flake.nml.IN',
#               'Test Info': ['export_fv3']},
#              'control_wrtGauss_netcdf_parallel_debug': {'CNTL_DIR': 'control_wrtGauss_netcdf_parallel_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'FHMAX': '1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'IOVR': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf_parallel'",
#               'IDEFLATE': '1',
#               'NBITS': '14',
#               'OUTPUT_FH': '0 1',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'control_stochy_debug': {'CNTL_DIR': 'control_stochy_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '600',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'FHMAX': '1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'IOVR': '3',
#               'OUTPUT_FH': '0 1',
#               'DO_SPPT': '.true.',
#               'DO_SHUM': '.true.',
#               'DO_SKEB': '.true.',
#               'SKEB': '0.3',
#               'SHUM': '0.003',
#               'SPPT': '0.2',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'cpld_control_c96_noaero_p8': {'CNTL_DIR': 'cpld_control_c96_noaero_p8',
#               'RESTART_N': '12',
#               'RESTART_INTERVAL': '${RESTART_N} -1',
#               'OUTPUT_FH': "'0 21 24'",
#               'TASKS': '$TASKS_cpl_c96',
#               'TPN': '$TPN_cpl_c96',
#               'INPES': '$INPES_cpl_c96',
#               'JNPES': '$JNPES_cpl_c96',
#               'THRD': '$THRD_cpl_c96',
#               'WRTTASK_PER_GROUP': '$WPG_cpl_c96',
#               'NPROC_ICE': '$NPROC_ICE_cpl_c96',
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'med_petlist_bounds': '$MPB_cpl_c96',
#               'atm_petlist_bounds': '$APB_cpl_c96',
#               'ocn_petlist_bounds': '$OPB_cpl_c96',
#               'ice_petlist_bounds': '$IPB_cpl_c96',
#               'CPLWAV': '.false.',
#               'CPLWAV2ATM': '.false.',
#               'MOM6_USE_WAVES': 'False',
#               'eps_imesh': '2.5e-1',
#               'DIAG_TABLE': 'diag_table_template',
#               'NEMS_CONFIGURE': 'nems.configure.cpld.IN',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'hafs_regional_atm_ocn': {'CNTL_DIR': 'hafs_regional_atm_ocn',
#               'HAFS': 'true',
#               'FHMAX': '6',
#               'RESTART_N': '${FHMAX}',
#               'TASKS': '360',
#               'DT_ATMOS': '180',
#               'IDEFLATE': '1',
#               'NFHMAX_HF': '-1',
#               'NFHOUT_HF': '3',
#               'NFHOUT': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf'",
#               'SDAY': '29',
#               'SHOUR': '00',
#               'SMONTH': '08',
#               'SYEAR': '2019',
#               'WRTTASK_PER_GROUP': '60',
#               'OUTPUT_GRID': "'regional_latlon'",
#               'CEN_LON': '-62.0',
#               'CEN_LAT': '22.0',
#               'LON1': '-116.90',
#               'LAT1': '-14.45',
#               'LON2': '-7.10',
#               'LAT2': '58.45',
#               'DLON': '0.1',
#               'DLAT': '0.1',
#               'BLOCKSIZE': '40',
#               'CCPP_SUITE': 'FV3_HAFS_v0_gfdlmp_tedmf_nonsst',
#               'DEFLATE_LEVEL': '-1',
#               'INPES': '20',
#               'JNPES': '12',
#               'NPX': '721',
#               'NPY': '601',
#               'NPZ': '91',
#               'NPZP': '$(($NPZ + 1))',
#               'K_SPLIT': '2',
#               'N_SPLIT': '5',
#               'NWAT': '6',
#               'NA_INIT': '1',
#               'EXTERNAL_IC': '.true.',
#               'NGGPS_IC': '.true.',
#               'MOUNTAIN': '.false.',
#               'WARM_START': '.false.',
#               'TARGET_LAT': '22.0',
#               'TARGET_LON': '-62.0',
#               'STRETCH_FAC': '1.0001',
#               'REGIONAL': '.true.',
#               'BC_UPDATE_INTERVAL': '3',
#               'NROWS_BLEND': '10',
#               'FULL_ZS_FILTER': '.false.',
#               'N_ZS_FILTER': '0',
#               'GRID_PES': '240',
#               'TILE_COARSE': '0',
#               'NUM_TILE_TOP': '1',
#               'NEST_REFINE': '0',
#               'NEST_IOFFSETS': '999',
#               'NEST_JOFFSETS': '999',
#               'FHCYC': '0',
#               'FHSWR': '1800',
#               'FHLWR': '1800',
#               'NSTF_NAME': '0,0,0,0,0',
#               'CPLFLX': '.true.',
#               'CPLOCN2ATM': '.true.',
#               'CPLWAV': '.false.',
#               'CPLWAV2ATM': '.false.',
#               'CPL_IMP_MRG': '.true.',
#               'CDEPS_DOCN': 'false',
#               'OCEAN_START_DTG': '43340.00000',
#               'atm_model': 'fv3',
#               'ocn_model': 'hycom',
#               'atm_petlist_bounds': '0000 0299',
#               'ocn_petlist_bounds': '0300 0359',
#               'med_petlist_bounds': '0300 0359',
#               'coupling_interval_sec': '360',
#               'MESH_ATM': 'unset',
#               'FIELD_TABLE': 'field_table_hafs',
#               'DIAG_TABLE': 'diag_table_hafs_template',
#               'INPUT_NML': 'input_regional_hafs.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_hafs_shared.IN',
#               'NEMS_CONFIGURE': 'nems.configure.hafs_atm_ocn.IN',
#               'FV3_RUN': 'hafs_fv3_run.IN hycom_hat10_run.IN',
#               'Test Info': ['export_fv3',
#                'export_hafs',
#                'export_hafs_regional']},
#              'rap_unified_drag_suite_debug': {'CNTL_DIR': 'rap_control_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '300',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'FHMAX': '1',
#               'OUTPUT_FH': '0 1',
#               '#WRITE_DOPOST': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_RAP_unified_ugwp',
#               'INPUT_NML': 'rap.nml.IN',
#               'FIELD_TABLE': 'field_table_thompson_aero_tke',
#               'NEW_DIAGTABLE': 'diag_table_rap',
#               'IMP_PHYSICS': '8',
#               'DNATS': '0',
#               'DO_SAT_ADJ': '.false.',
#               'LRADAR': '.true.',
#               'LTAEROSOL': '.true.',
#               'IALB': '2',
#               'IEMS': '2',
#               'HYBEDMF': '.false.',
#               'DO_MYNNEDMF': '.true.',
#               'DO_MYNNSFCLAY': '.true.',
#               'IMFSHALCNV': '3',
#               'IMFDEEPCNV': '3',
#               'LSM': '3',
#               'LSOIL_LSM': '9',
#               'KICE': '9',
#               'GWD_OPT': '2',
#               'DO_UGWP_V0': '.false.',
#               'DO_UGWP_V0_OROG_ONLY': '.false.',
#               'DO_GSL_DRAG_LS_BL': '.true.',
#               'DO_GSL_DRAG_SS': '.true.',
#               'DO_GSL_DRAG_TOFD': '.true.',
#               'DO_UGWP_V1': '.false.',
#               'DO_UGWP_V1_OROG_ONLY': '.false.',
#               'Test Info': ['export_fv3']},
#              'control_wam_debug': {'CNTL_DIR': 'control_wam_debug',
#               'NPZ': '149',
#               'NPZP': '150',
#               'DT_ATMOS': '225',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'FHMAX': '19',
#               'OUTPUT_FH': '0 19',
#               '#WRITE_DOPOST': '.true.',
#               'WARM_START': '.true.',
#               'NA_INIT': '0',
#               'EXTERNAL_IC': '.false.',
#               'NGGPS_IC': '.false.',
#               'MAKE_NH': '.false.',
#               'MOUNTAIN': '.true.',
#               'FDIAG': '3',
#               'NSTF_NAME': '0,0,1,0,5',
#               'IAER': '5111',
#               'DO_SAT_ADJ': '.false.',
#               'FV3_RUN': 'wam_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_fv3wam',
#               'INPUT_NML': 'wam.nml.IN',
#               'DIAG_TABLE': 'diag_table_wam',
#               'FIELD_TABLE': 'field_table_wam',
#               'QUILTING': '.true.',
#               'OUTPUT_GRID': 'gaussian_grid',
#               'OZ_PHYS_OLD': '.false.',
#               'OZ_PHYS_NEW': '.true.',
#               'H2O_PHYS': '.true.',
#               'NFHOUT': '6',
#               'NFHMAX': '24',
#               'NFHOUT_HF': '6',
#               'FHROT': '18',
#               'Test Info': ['export_fv3']},
#              'control_ras_debug': {'CNTL_DIR': 'control_ras_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'FHMAX': '1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'IOVR': '3',
#               'OUTPUT_FH': '0 1',
#               'RAS': '.true.',
#               'IMFDEEPCNV': '-1',
#               'CNVCLD': '.false.',
#               'RANDOM_CLDS': '.true.',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16_ras',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']},
#              'control_c384gdas_debug': {'CNTL_DIR': 'control_c384gdas_debug',
#               'TASKS': '${TASKS_c384}',
#               'TPN': '${TPN_c384}',
#               'INPES': '${INPES_c384}',
#               'JNPES': '${JNPES_c384}',
#               'WRITE_GROUP': '1',
#               'WRTTASK_PER_GROUP': '48',
#               'FHMAX': '7',
#               'NPZ': '127',
#               'NPZP': '128',
#               'NPX': '385',
#               'NPY': '385',
#               'DT_ATMOS': '225',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '21',
#               'SHOUR': '18',
#               'FHROT': '3',
#               'OUTPUT_FH': '0 1',
#               'NFHMAX_HF': '7',
#               'IAU_OFFSET': '6',
#               'CDMBWD': '${CDMBWD_c384}',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'IMO': '1536',
#               'JMO': '768',
#               'WARM_START': '.true.',
#               'NGGPS_IC': '.false.',
#               'EXTERNAL_IC': '.false.',
#               'MAKE_NH': '.false.',
#               'MOUNTAIN': '.true.',
#               'NA_INIT': '0',
#               'IAU_INC_FILES': "'fv_increment3.nc','fv_increment6.nc','fv_increment9.nc'",
#               'MODEL_INITIALIZATION': 'true',
#               'FNALBC': "'global_snowfree_albedo.bosu.t766.1536.768.rg.grb',",
#               'FNVETC': "'global_vegtype.igbp.t766.1536.768.rg.grb',",
#               'FNSOTC': "'global_soiltype.statsgo.t766.1536.768.rg.grb',",
#               'FNABSC': "'global_mxsnoalb.uariz.t766.1536.768.rg.grb',",
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control_gdas.nml.IN',
#               'Test Info': ['export_fv3']},
#              'regional_debug': {'CNTL_DIR': 'fv3_regional_debug',
#               'FV3_RUN': 'regional_run.IN',
#               'OZ_PHYS_OLD': '.F.',
#               'OZ_PHYS_NEW': '.T.',
#               'H2O_PHYS': '.T.',
#               'HYBEDMF': '.F.',
#               'POSTAPP': "'lam'",
#               'CCPP_SUITE': 'FV3_GFS_v15_thompson_mynn',
#               'INPUT_NML': 'regional.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_regional.IN',
#               'DIAG_TABLE': 'diag_table_lam',
#               'FIELD_TABLE': 'field_table_regional',
#               'FDIAG': '1',
#               'FHMAX': '1',
#               'TASKS': '68',
#               'INPES': '10',
#               'JNPES': '6',
#               'OUTPUT_FH': '0 1',
#               'WLCLK': '30',
#               'Test Info': ['export_fv3']},
#              'hafs_regional_docn': {'CNTL_DIR': 'hafs_regional_docn',
#               'HAFS': 'true',
#               'FHMAX': '6',
#               'RESTART_N': '${FHMAX}',
#               'TASKS': '360',
#               'DT_ATMOS': '180',
#               'IDEFLATE': '1',
#               'NFHMAX_HF': '-1',
#               'NFHOUT_HF': '3',
#               'NFHOUT': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf'",
#               'SDAY': '29',
#               'SHOUR': '00',
#               'SMONTH': '08',
#               'SYEAR': '2019',
#               'WRTTASK_PER_GROUP': '60',
#               'OUTPUT_GRID': "'regional_latlon'",
#               'CEN_LON': '-62.0',
#               'CEN_LAT': '22.0',
#               'LON1': '-116.90',
#               'LAT1': '-14.45',
#               'LON2': '-7.10',
#               'LAT2': '58.45',
#               'DLON': '0.1',
# ...
#               'FNSOTC': "'global_soiltype.statsgo.t766.1536.768.rg.grb',",
#               'FNABSC': "'global_mxsnoalb.uariz.t766.1536.768.rg.grb',",
#               'CPL': '.true.',
#               'CPLWAV': '.true.',
#               'NEMS_CONFIGURE': 'nems.configure.leapfrog_atm_wav.IN',
#               'atm_model': "'fv3'",
#               'wav_model': "'ww3'",
#               'WW3OUTPUTTYPE': "' 1'",
#               'coupling_interval_sec': '1800.0  #coupling time step, want it to be multiple of 1800 and FV3 time step',
#               'WW3RSTDTHR': '9',
#               'DT_2_RST': '$(printf %02d $(( ${WW3RSTDTHR}*3600 )))',
#               'NFGRIDS': '1',
#               'NMGRIDS': '3',
#               'CPLILINE': "'glo_15mxt'  F F T F F F F F F",
#               'WW3GRIDLINE': "'gnh_10m' 'no' 'no' 'CPL:glo_15mxt' 'no'  'no' 'no' 'no' 'no' 'no' 1 10  0.00 1.00  F",
#               'RUN_BEG': '${SYEAR}${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'RUN_END': '2100${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'OUT_BEG': '$RUN_BEG',
#               'OUT_END': '$RUN_END',
#               'RST_BEG': '$RUN_BEG',
#               'RST_2_BEG': '$RUN_BEG',
#               'RST_END': '$RUN_END',
#               'RST_2_END': '$RUN_END',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control_gdas.nml.IN',
#               'Test Info': ['export_fv3']},
#              'hafs_regional_atm_wav': {'CNTL_DIR': 'hafs_regional_atm_wav',
#               'HAFS': 'true',
#               'FHMAX': '6',
#               'RESTART_N': '${FHMAX}',
#               'TASKS': '420',
#               'DT_ATMOS': '180',
#               'IDEFLATE': '1',
#               'NFHMAX_HF': '-1',
#               'NFHOUT_HF': '3',
#               'NFHOUT': '3',
#               'OUTPUT_FILE': "'netcdf_parallel' 'netcdf'",
#               'SDAY': '29',
#               'SHOUR': '00',
#               'SMONTH': '08',
#               'SYEAR': '2019',
#               'WRTTASK_PER_GROUP': '60',
#               'OUTPUT_GRID': "'regional_latlon'",
#               'CEN_LON': '-62.0',
#               'CEN_LAT': '22.0',
#               'LON1': '-116.90',
#               'LAT1': '-14.45',
#               'LON2': '-7.10',
#               'LAT2': '58.45',
#               'DLON': '0.1',
#               'DLAT': '0.1',
#               'BLOCKSIZE': '40',
#               'CCPP_SUITE': 'FV3_HAFS_v0_gfdlmp_tedmf',
#               'DEFLATE_LEVEL': '-1',
#               'INPES': '20',
#               'JNPES': '12',
#               'NPX': '721',
#               'NPY': '601',
#               'NPZ': '91',
#               'NPZP': '$(($NPZ + 1))',
#               'K_SPLIT': '2',
#               'N_SPLIT': '5',
#               'NWAT': '6',
#               'NA_INIT': '1',
#               'EXTERNAL_IC': '.true.',
#               'NGGPS_IC': '.true.',
#               'MOUNTAIN': '.false.',
#               'WARM_START': '.false.',
#               'TARGET_LAT': '22.0',
#               'TARGET_LON': '-62.0',
#               'STRETCH_FAC': '1.0001',
#               'REGIONAL': '.true.',
#               'BC_UPDATE_INTERVAL': '3',
#               'NROWS_BLEND': '10',
#               'FULL_ZS_FILTER': '.false.',
#               'N_ZS_FILTER': '0',
#               'GRID_PES': '240',
#               'TILE_COARSE': '0',
#               'NUM_TILE_TOP': '1',
#               'NEST_REFINE': '0',
#               'NEST_IOFFSETS': '999',
#               'NEST_JOFFSETS': '999',
#               'FHCYC': '0',
#               'FHSWR': '1800',
#               'FHLWR': '1800',
#               'NSTF_NAME': '2,0,0,0,0',
#               'CPLFLX': '.true.',
#               'CPLOCN2ATM': '.false.',
#               'CPLWAV': '.true.',
#               'CPLWAV2ATM': '.true.',
#               'CPL_IMP_MRG': '.true.',
#               'FLD_DT': '10800',
#               'PNT_DT': '10800',
#               'GOFILETYPE': '',
#               'POFILETYPE': '',
#               'OUTPARS_WAV': 'WND HS T01 T02 DIR FP DP PHS PTP PDIR UST CHA USP',
#               'UNIPOINTS': "'ww3'",
#               'WW3GRIDLINE': "'ww3' 'no' 'no' 'CPL:native' 'no' 'no' 'no' 'no' 'no' 'no'  1  1  0.00 1.00  F",
#               'WW3RSTDTHR': '${FHMAX}',
#               'DT_2_RST': '$(printf %02d $(( ${WW3RSTDTHR}*3600 )))',
#               'RUN_BEG': '${SYEAR}${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'RUN_END': '20190829 060000',
#               'OUT_BEG': '$RUN_BEG',
#               'OUT_END': '$RUN_END',
#               'RST_BEG': '$RUN_BEG',
#               'RST_2_BEG': '$RUN_BEG',
#               'RST_END': '$RUN_END',
#               'RST_2_END': '$RUN_END',
#               'CDEPS_DOCN': 'false',
#               'OCEAN_START_DTG': '43340.00000',
#               'atm_model': 'fv3',
#               'ocn_model': '',
#               'wav_model': 'ww3',
#               'atm_petlist_bounds': '0000 0299',
#               'ocn_petlist_bounds': '',
#               'med_petlist_bounds': '0300 0359',
#               'wav_petlist_bounds': '0360 0419',
#               'coupling_interval_sec': '360',
#               'MESH_ATM': 'unset',
#               'FIELD_TABLE': 'field_table_hafs',
#               'DIAG_TABLE': 'diag_table_hafs_template',
#               'INPUT_NML': 'input_regional_hafs.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_hafs_shared.IN',
#               'NEMS_CONFIGURE': 'nems.configure.hafs_atm_wav.IN',
#               'FV3_RUN': 'hafs_fv3_run.IN hafs_ww3_run.IN',
#               'Test Info': ['export_fv3',
#                'export_hafs',
#                'export_hafs_regional']},
#              'datm_cdeps_gfs': {'CNTL_DIR': 'datm_cdeps_gfs',
#               'DATM_SRC': 'GFS',
#               'FILENAME_BASE': "'gfs.'",
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'SECS': '`expr $SHOUR \\* 3600`',
#               'IATM': '3072',
#               'JATM': '1536',
#               'ATM_NX_GLB': '$IATM',
#               'ATM_NY_GLB': '$JATM',
#               'ATMRES': '3072x1536',
#               'mesh_file': 'gfs_mesh.nc',
#               'MESH_ATM': 'DATM_INPUT/${mesh_file}',
#               'atm_datamode': 'GFS',
#               'KTHERM': '2',
#               'TFREEZE_OPTION': 'mushy',
#               'RESTART_N': '12',
#               'stream_files': 'DATM_INPUT/gfs.202103.nc',
#               'eps_imesh': "'2.5e-1'",
#               'FV3_RUN': 'cpld_datm_cdeps_gfs.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'regional_hafs': {'CNTL_DIR': 'fv3_regional_hafs',
#               'TASKS': '68',
#               'FV3_RUN': 'regional_run.IN',
#               'OZ_PHYS_OLD': '.false.',
#               'OZ_PHYS_NEW': '.true.',
#               'H2O_PHYS': '.true.',
#               'HYBEDMF': '.false.',
#               'WRITE_DOPOST': '.true.',
#               'POSTAPP': "'hafs'",
#               'CCPP_SUITE': 'FV3_GFS_v15_thompson_mynn',
#               'INPUT_NML': 'regional.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_hafs.IN',
#               'DIAG_TABLE': 'diag_table_lam',
#               'FIELD_TABLE': 'field_table_regional',
#               'INPES': '10',
#               'JNPES': '6',
#               'Test Info': ['export_fv3']},
#              'datm_cdeps_bulk_gefs': {'CNTL_DIR': 'datm_cdeps_bulk_gefs',
#               'atm_datamode': 'GEFS',
#               'IATM': '1536',
#               'JATM': '768',
#               'ATM_NX_GLB': '$IATM',
#               'ATM_NY_GLB': '$JATM',
#               'ATMRES': "'1536x768'",
#               'DATM_SRC': 'GEFS',
#               'FILENAME_BASE': "'gefs.'",
#               'mesh_file': 'gefs_mesh.nc',
#               'MESH_ATM': 'DATM_INPUT/${mesh_file}',
#               'stream_files': 'DATM_INPUT/${FILENAME_BASE}201110.nc',
#               'RESTART_N': '12',
#               'flux_scheme': "'-1'",
#               'eps_imesh': "'2.5e-1'",
#               'FV3_RUN': 'cpld_datm_cdeps.IN',
#               'Test Info': ['export_datm_cdeps']},
#              'control_lndp_debug': {'CNTL_DIR': 'control_lndp_debug',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'FHMAX': '1',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'IAER': '5111',
#               'OUTPUT_FH': '0 1',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control_ca.nml.IN',
#               'DO_CA': '.false.',
#               'CA_SGS': '.false.',
#               'CA_GLOBAL': '.false.',
#               'NLIVES': '12',
#               'NCELLS': '5',
#               'NSEED': '1',
#               'NTHRESH': '18',
#               'CA_SMOOTH': '.false.',
#               'NSPINUP': '1',
#               'ISEED_CA': '1',
#               'NSMOOTH': '1',
#               'CA_AMPLITUDE': '0.35',
#               'LNDP_TYPE': '2',
#               'N_VAR_LNDP': '2',
#               'LNDP_VAR_LIST': "'smc' , 'vgf',",
#               'LNDP_PRT_LIST': "'0.2,0.1,'",
#               'Test Info': ['export_fv3']},
#              'cpld_bmark_p8_35d': {'CNTL_DIR': 'cpld_bmark_p8',
#               'SDAY': '01',
#               'SHOUR': '00',
#               'SECS': '`expr $SHOUR \\* 3600`',
#               'BMIC': '.true.',
#               'DAYS': '5',
#               'FHMAX': '120',
#               'RESTART_N': '`expr ${FHMAX} - ${FHROT}`',
#               'WLCLK': '120',
#               'TASKS': '1700',
#               'TPN': '$TPN_cpl_thrd',
#               'INPES': '12',
#               'JNPES': '16',
#               'THRD': '2',
#               'WRTTASK_PER_GROUP': '88',
#               'med_petlist_bounds': '0 299',
#               'atm_petlist_bounds': '0 1239',
#               'ocn_petlist_bounds': '1240 1459',
#               'ice_petlist_bounds': '1460 1539',
#               'wav_petlist_bounds': '1540 1699',
#               'ATMRES': 'C384',
#               'NPX': '385',
#               'NPY': '385',
#               'IMO': '1536',
#               'JMO': '768',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'ATMTILESIZE': '`expr $NPX - 1`',
#               'OCNRES': '025',
#               'ICERES': '0.25',
#               'NX_GLB': '1440',
#               'NY_GLB': '1080',
#               'NPROC_ICE': '80',
#               'np2': '`expr $NPROC_ICE / 2`',
#               'BLCKX': '`expr $NX_GLB / $np2`',
#               'BLCKY': '`expr $NY_GLB / 2`',
#               'DT_ATMOS': '300',
#               'DT_CICE': '${DT_ATMOS}',
#               'DT_DYNAM_MOM6': '900',
#               'DT_THERM_MOM6': '1800',
#               'NEMS_CONFIGURE': 'nems.configure.cpld_wave.IN',
#               'coupling_interval_slow_sec': '${DT_THERM_MOM6}',
#               'coupling_interval_fast_sec': '${DT_ATMOS}',
#               'MOM_INPUT': 'MOM_input_template_${OCNRES}',
#               'MESHOCN_ICE': 'mesh.mx${OCNRES}.nc',
#               'CICEGRID': 'grid_cice_NEMS_mx${OCNRES}.nc',
#               'CICEMASK': 'kmtu_cice_NEMS_mx${OCNRES}.nc',
#               'CHLCLIM': 'seawifs-clim-1997-2010.${NX_GLB}x${NY_GLB}.v20180328.nc',
#               'FRUNOFF': 'runoff.daitren.clim.${NX_GLB}x${NY_GLB}.v20180328.nc',
#               'FNALBC': "'C384.snowfree_albedo.tileX.nc'",
#               'FNALBC2': "'C384.facsf.tileX.nc'",
#               'FNTG3C': "'C384.substrate_temperature.tileX.nc'",
#               'FNVEGC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNVETC': "'C384.vegetation_type.tileX.nc'",
#               'FNSOTC': "'C384.soil_type.tileX.nc'",
#               'FNVMNC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNVMXC': "'C384.vegetation_greenness.tileX.nc'",
#               'FNSLPC': "'C384.slope_type.tileX.nc'",
#               'FNABSC': "'C384.maximum_snow_albedo.tileX.nc'",
#               'CDMBWD': '${CDMBWD_c384}',
#               'DT_INNER': '${DT_INNER_c384}',
#               'MOM6_RIVER_RUNOFF': 'True',
#               'MOM6_RESTART_SETTING': 'r',
#               'WW3GRIDLINE': "'gwes_30m' 'no' 'CPL:native' 'CPL:native' 'CPL:native' 'no' 'no' 'no' 'no' 'no'  1  1  0.00 1.00  F",
#               'WW3RSTDTHR': '${FHMAX}',
#               'DT_2_RST': '$(printf %02d $(( ${WW3RSTDTHR}*3600 )))',
#               'RUN_BEG': '${SYEAR}${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'RUN_END': '2100${SMONTH}${SDAY} $(printf %02d $(( ${SHOUR}  )))0000',
#               'OUT_BEG': '$RUN_BEG',
#               'OUT_END': '$RUN_END',
#               'RST_BEG': '$RUN_BEG',
#               'RST_2_BEG': '$RUN_BEG',
#               'RST_END': '$RUN_END',
#               'RST_2_END': '$RUN_END',
#               'DIAG_TABLE': 'diag_table_template',
#               'FV3_RUN': 'cpld_control_run.IN',
#               'Test Info': ['export_fv3', 'export_cpl']},
#              'regional_3km': {'CNTL_DIR': 'fv3_regional_3km',
#               'FV3_RUN': 'regional_3km_run.IN',
#               'OZ_PHYS_OLD': '.false.',
#               'OZ_PHYS_NEW': '.true.',
#               'H2O_PHYS': '.true.',
#               'HYBEDMF': '.false.',
#               'RESTART_INTERVAL': '0',
#               'WRITE_DOPOST': '.true.',
#               'POSTAPP': "'lam'",
#               'CCPP_SUITE': 'FV3_GFS_v15_thompson_mynn_lam3km',
#               'INPUT_NML': 'regional_3km.nml.IN',
#               'MODEL_CONFIGURE': 'model_configure_regional_3km.IN',
#               'DIAG_TABLE': 'diag_table_lam',
#               'FIELD_TABLE': 'field_table_regional',
#               'WLCLK': '10',
#               'FHMAX': '6',
#               'TASKS': '120',
#               'INPES': '10',
#               'JNPES': '11',
#               'OUTPUT_FH': '3 -1',
#               'Test Info': ['export_fv3']},
#              'control_atm_aerosols': {'CNTL_DIR': 'control_atm_aerosols',
#               'NPZ': '127',
#               'NPZP': '128',
#               'DT_ATMOS': '720',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': "'12 -1'",
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'IOVR': '3',
#               'FSCAV_AERO': "'*:0.6, seas1:1.0, seas2:1.0, seas3:1.0, seas4:1.0, seas5:1.0'",
#               'DNATS': '3',
#               'CPL': '.true.',
#               'CPLCHM': '.true.',
#               'atm_model': "'fv3'",
#               'atm_petlist_bounds': '0 149',
#               'chm_model': "'gocart'",
#               'chm_petlist_bounds': '0 143',
#               'coupling_interval_sec': '${DT_ATMOS}',
#               'NEMS_CONFIGURE': 'nems.configure.atm_aerosols.IN',
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'DIAG_TABLE': 'diag_table_GOCART',
#               'FIELD_TABLE': 'field_table_GOCART',
#               'Test Info': ['export_fv3']},
#              'control_c192': {'CNTL_DIR': 'control_c192',
#               'TASKS': '204',
#               'INPES': '4',
#               'WRTTASK_PER_GROUP': '12',
#               'NPZ': '127',
#               'NPZP': '128',
#               'NPX': '193',
#               'NPY': '193',
#               'DT_ATMOS': '360',
#               'SYEAR': '2021',
#               'SMONTH': '03',
#               'SDAY': '22',
#               'SHOUR': '06',
#               'RESTART_INTERVAL': '48',
#               'CDMBWD': '${CDMBWD_c192}',
#               'OUTPUT_GRID': "'gaussian_grid'",
#               'NSTF_NAME': "'2,0,0,0,0'",
#               'WRITE_DOPOST': '.true.',
#               'IAER': '5111',
#               'IOVR': '3',
#               'IMO': '768',
#               'JMO': '384',
#               'FNALBC': "'global_snowfree_albedo.bosu.t382.768.384.rg.grb',",
#               'FNVETC': "'global_vegtype.igbp.t382.768.384.rg.grb',",
#               'FNSOTC': "'global_soiltype.statsgo.t382.768.384.rg.grb',",
#               'FNABSC': "'global_mxsnoalb.uariz.t382.768.384.rg.grb',",
#               'FV3_RUN': 'control_run.IN',
#               'CCPP_SUITE': 'FV3_GFS_v16',
#               'INPUT_NML': 'control.nml.IN',
#               'Test Info': ['export_fv3']}})

# %% [markdown]
# # Demo: Mapping of UFS Application-to-Physics Suite Build to Regression Tests & their Corresponding Configuration Files, CNTL Folder, & Regression Test Parameters.
#
# Maps each UFS Applications-to-Physics Suite to their corresponding:
# - Applicable Tests
#
# Maps each regression test to their corresponding:
# - CNTL folder
# - Configuration Files (FV3_conf)
# - Parameters (parm)
# - Test Details
# - Test Type

# %%
# Read map from pickle file.
appsphys2test_df = scraper_wrapper.read_pickle('./ufs_repo_mapped_data/rt_appsphys2test_df')
#appsphys2test_df.head(50)
appsphys2test_df
# Out:
#       UFS_App                         Physics_Suite    Test Type  \
# 0        S2SW  FV3_GFS_v16_coupled_nsstNoahmpUGWPv1        tests
# 1        S2SW  FV3_GFS_v16_coupled_nsstNoahmpUGWPv1        tests
# 2        S2SW  FV3_GFS_v16_coupled_nsstNoahmpUGWPv1        tests
# 3        S2SW  FV3_GFS_v16_coupled_nsstNoahmpUGWPv1        tests
# 4        S2SW  FV3_GFS_v16_coupled_nsstNoahmpUGWPv1        tests
# ..        ...                                   ...          ...
# 599  NG-GODAS                                              tests
# 600  NG-GODAS                                        debug_tests
# 601      ATMW                           FV3_GFS_v16        tests
# 602      ATMW                           FV3_GFS_v16        tests
# 603   ATMAERO                          FV3_GFS_v16         tests
#
#                      Test Name  \
# 0              cpld_control_p8
# 1             cpld_2threads_p8
# 2               cpld_decomp_p8
# 3                  cpld_mpi_p8
# 4       cpld_control_p7_rrtmgp
# ..                         ...
# 599  datm_cdeps_3072x1536_cfsr
# 600      datm_cdeps_debug_cfsr
# 601             control_atmwav
# 602       control_c384gdas_wav
# 603       control_atm_aerosols
#
#                                              Test Info  \
# 0    {'CNTL_DIR': 'cpld_control_p8', 'RESTART_N': '...
# 1    {'CNTL_DIR': 'cpld_control_p8', 'RESTART_N': '...
# 2    {'CNTL_DIR': 'cpld_control_p8', 'RESTART_N': '...
# 3    {'CNTL_DIR': 'cpld_control_p8', 'RESTART_N': '...
# 4    {'CNTL_DIR': 'cpld_control_p7_rrtmgp', 'RESTAR...
# ..                                                 ...
# 599  {'CNTL_DIR': 'datm_cdeps_3072x1536_cfsr', 'DAT...
# 600  {'CNTL_DIR': 'datm_cdeps_debug_cfsr', 'DATM_SR...
# 601  {'CNTL_DIR': 'control_atmwav', 'NPZ': '127', '...
# 602  {'CNTL_DIR': 'control_c384gdas_wav', 'FHMAX': ...
# 603  {'CNTL_DIR': 'control_atm_aerosols', 'NPZ': '1...
#
#                    CNTL Folder             FV3 File  \
# 0              cpld_control_p8  cpld_control_run.IN
# 1              cpld_control_p8  cpld_control_run.IN
# 2              cpld_control_p8  cpld_control_run.IN
# 3              cpld_control_p8  cpld_control_run.IN
# 4       cpld_control_p7_rrtmgp  cpld_control_run.IN
# ..                         ...                  ...
# 599  datm_cdeps_3072x1536_cfsr   cpld_datm_cdeps.IN
# 600      datm_cdeps_debug_cfsr   cpld_datm_cdeps.IN
# 601             control_atmwav       control_run.IN
# 602       control_c384gdas_wav       control_run.IN
# 603       control_atm_aerosols       control_run.IN
#
#                       Parm File
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4    cpld_control_rrtmgp.nml.IN
# ..                          ...
# 599                         NaN
# 600                         NaN
# 601              control.nml.IN
# 602         control_gdas.nml.IN
# 603              control.nml.IN
#
# [604 rows x 8 columns]

# %% [markdown]
# # Demo: Select UFS Application-to-Physics Suite Build & Regression Test of Interest

# %%
# App-to-Physics combo to Test file dictionary
unique_app2phys = ('ATM', 'FV3_GFS_v16_RRTMGP')
test_type = 'debug_tests'
test_name = 'control_thompson_no_aero_debug'
fv3_file = appsphys2test_dict[unique_app2phys][test_type][test_name]['FV3_RUN']
parm_file = appsphys2test_dict[unique_app2phys][test_type][test_name]['INPUT_NML']

print("\nUFS APPLICATION-to-PHYSICS SUITE:\n", unique_app2phys)
print("\nTEST NAME:\n", test_name)
print("\nFV3:\n", fv3_file)
print("\nPARM:\n", parm_file)

# Parameters of the Regression Test of Interest.
print("\nParameters of the Given App-to-Physics Regression Test:\n", appsphys2test_dict[unique_app2phys][test_type][test_name])

# FV3 files dictionary associated w/ the Regression Test of Interest.
unique_fv3_file = fv3_file
print("\nFV3 Mentioned Files Being Linked, Synced, Copied:\n", input_data_dict['fv3_conf'][unique_fv3_file])

# Parm files associated w/ the Regression Test of Interest.
unique_parm_file = parm_file
print("\nParm Mentioned Files:\n", input_data_dict['parm'][unique_parm_file])
# Out:
# UFS APPLICATION-to-PHYSICS SUITE:
#  ('ATM', 'FV3_GFS_v16_RRTMGP')
#
# TEST NAME:
#  control_thompson_no_aero_debug
#
# FV3:
#  control_run.IN
#
# PARM:
#  control_thompson.nml.IN
#
# Parameters of the Given App-to-Physics Regression Test:
#  {'CNTL_DIR': 'control_thompson_no_aero_debug', 'NPZ': '127', 'NPZP': '128', 'DT_ATMOS': '600', 'SYEAR': '2021', 'SMONTH': '03', 'SDAY': '22', 'SHOUR': '06', 'OUTPUT_GRID': "'gaussian_grid'", 'NSTF_NAME': "'2,0,0,0,0'", 'FHMAX': '1', 'OUTPUT_FH': '0 1', 'IMP_PHYSICS': '8', 'DNATS': '0', 'DO_SAT_ADJ': '.false.', 'LRADAR': '.true.', 'NSRADAR_RESET': '3600.0', 'LTAEROSOL': '.false.', 'HYBEDMF': '.false.', 'SATMEDMF': '.true.', 'DO_MYNNEDMF': '.false.', 'IMFSHALCNV': '2', 'IMFDEEPCNV': '2', 'IAER': '5111', 'ICLIQ_SW': '2', 'IOVR': '3', 'LHEATSTRG': '.true.', 'DO_TOFD': '.T', 'FV3_RUN': 'control_run.IN', 'CCPP_SUITE': 'FV3_GFS_v16_thompson', 'INPUT_NML': 'control_thompson.nml.IN', 'FIELD_TABLE': 'field_table_thompson_noaero_tke', 'Test Info': ['export_fv3']}
#
# FV3 Mentioned Files Being Linked, Synced, Copied:
#  defaultdict(<class 'list'>, {'@[INPUTDATA_ROOT]/${inputdir}/INPUT_L127/*': ['./INPUT/.'], '${FILEDIR}/../INPUT/fv3_increment.nc': ['INPUT/.'], '${FILEDIR}/../INPUT/grid_spec.nc': ['INPUT/.', 'INPUT/.'], '${FILEDIR}/../INPUT/*_grid.tile*.nc': ['INPUT/.', 'INPUT/.'], '${FILEDIR}/../INPUT/oro_data.tile*.nc': ['INPUT/.'], '${FILEDIR}/fv_increment*.nc': ['INPUT/.'], '${FILEDIR}/grid_spec.nc': ['INPUT/.'], '${FILEDIR}/*_grid.tile*.nc': ['INPUT/.'], '${FILEDIR}/oro_data.tile*.nc': ['INPUT/.'], '${FILEDIR}/coupler.res': ['INPUT/.'], '${FILEDIR}/fv_core.res.*': ['INPUT/.'], '${FILEDIR}/fv_srf_wnd.res.*': ['INPUT/.'], '${FILEDIR}/fv_tracer.*': ['INPUT/.'], '${FILEDIR}/phy_data.*': ['INPUT/.'], '${FILEDIR}/sfc_data.*': ['INPUT/.'], '../${DEP_RUN}${SUFFIX}/RESTART/${RESTART_FILE_PREFIX}.*': ['./INPUT'], '${FILEDIR}/../INPUT/oro_data*.nc': ['INPUT/.'], '$RFILE': ['INPUT/${RFILE_NEW}'], '@[INPUTDATA_ROOT]/FV3_fix_tiled/@[ATMRES]/@[ATMRES]*.nc': ['.'], '@[INPUTDATA_ROOT]/FV3_fix/global_glacier.2x2.grb': ['.'], '@[INPUTDATA_ROOT]/FV3_fix/global_maxice.2x2.grb': ['.'], '@[INPUTDATA_ROOT]/FV3_fix/RTGSST.1982.2012.monthly.clim.grb': ['.'], '@[INPUTDATA_ROOT]/FV3_fix/global_snoclim.1.875.grb': ['.'], '@[INPUTDATA_ROOT]/FV3_fix/CFSR.SEAICE.1982.2012.monthly.clim.grb': ['.'], '@[INPUTDATA_ROOT]/${inputdir}/@[FNSMCC]': ['.'], '@[INPUTDATA_ROOT]/${inputdir}/@[FNMSKH_control]': ['.'], '@[INPUTDATA_ROOT]/${inputdir}/*grb': ['.'], '@[INPUTDATA_ROOT_WW3]/mod_def.*': ['.'], '@[INPUTDATA_ROOT_WW3]/rmp_src*': ['.'], '${PATHRT}/parm/post_itag': ['itag'], '${PATHRT}/parm/postxconfig-NT.txt': ['postxconfig-NT.txt'], '${PATHRT}/parm/postxconfig-NT_FH00.txt': ['postxconfig-NT_FH00.txt'], '${PATHRT}/parm/params_grib2_tbl_new': ['params_grib2_tbl_new'], '@[INPUTDATA_ROOT]/FV3_input_data_RRTMGP/*': ['.'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/MERRA2/merra2.aerclim.2003-2014.m${n}.nc': ['aeroclim.m${n}.nc'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/aer_data/LUTS/optics_BC.v1_3.dat': ['optics_BC.dat'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/aer_data/LUTS/optics_OC.v1_3.dat': ['optics_OC.dat'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/aer_data/LUTS/optics_DU.v15_3.dat': ['optics_DU.dat'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/aer_data/LUTS/optics_SS.v3_3.dat': ['optics_SS.dat'], '@[INPUTDATA_ROOT]/FV3_input_data_INCCN_aeroclim/aer_data/LUTS/optics_SU.v1_3.dat': ['optics_SU.dat'], '@[INPUTDATA_ROOT]/FV3_input_data/ugwp_c384_tau.nc': ['./ugwp_limb_tau.nc'], '@[INPUTDATA_ROOT]/FV3_input_data_gsd/qr_acr_qsV2.dat': ['.'], '@[INPUTDATA_ROOT]/FV3_input_data_gsd/qr_acr_qgV2.dat': ['.'], '@[INPUTDATA_ROOT]/FV3_input_data_gsd/freezeH2O.dat': ['.'], '@[INPUTDATA_ROOT]/FV3_input_data_gsd/CCN_ACTIVATE.BIN': ['.'], '${PATHRT}/parm/gocart/*.rc': ['.'], '@[INPUTDATA_ROOT]/GOCART/ExtData': ['.']})
#
# Parm Mentioned Files:
#  ['global_glacier.2x2.grb', 'global_maxice.2x2.grb', 'RTGSST.1982.2012.monthly.clim.grb', 'global_snoclim.1.875.grb', 'global_albedo4.1x1.grb', 'CFSR.SEAICE.1982.2012.monthly.clim.grb', 'global_tg3clim.2.6x1.5.grb', 'global_vegfrac.0.144.decpercent.grb', 'global_soilmgldas.statsgo.t1534.3072.1536.grb', 'global_slmask.t1534.3072.1536.grb', 'global_shdmin.0.144x0.144.grb', 'global_shdmax.0.144x0.144.grb', 'global_slope.1x1.grb', 'INPUT/grid_spec.nc']
